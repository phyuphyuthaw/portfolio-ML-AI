# %%
# !pip install opencv-python
#!pip install albumentations

# %%
# !pip install pycocotools --quiet
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0

# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./

# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import sys
sys.path.append('/content/gdrive/MyDrive/Colab Notebooks/Faster RCNN')

# %%
# Directories to image files and annotation folder
file_dir = '/content/gdrive/MyDrive/Colab Notebooks/GC-10/IMAGES'
annotation_dir = '/content/gdrive/MyDrive/Colab Notebooks/GC-10/ANNOTATIONS'

# %%
# Import required python basic packages
import os
import random
import numpy as np
import pandas as pd
import glob

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Import opencv
import cv2

# XML library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchutils library
from torch.utils.data import DataLoader, random_split

# torchvision libraries
import torch
import torchvision
from torchvision import transforms as torchtrans
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator

# these are the helper libraries imported.
import engine
import transforms as T
import utils
from engine import train_one_epoch, evaluate

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
# Import dataset
# define the train and test file directories

class GC10Dataset(torch.utils.data.Dataset):
    def __init__(self, file_dir, annotation_dir, width, height, transforms=None):
        self.transforms = transforms
        self.file_dir = file_dir
        self.annotation_dir = annotation_dir
        self.width = width
        self.height = height

        # Get all images
        all_imgs = glob.glob(os.path.join(file_dir, '**/*.jpg'), recursive=True)

        # Filter images that have corresponding annotation XML files
        self.imgs = []
        for img in all_imgs:
            annot_filename = os.path.splitext(os.path.basename(img))[0] + '.xml'
            annot_file_path = os.path.join(self.annotation_dir, annot_filename)

            if os.path.exists(annot_file_path):
                self.imgs.append(img)  # Only add if annotation file exists
            # else:
                # print(f"Warning: Annotation file for {img} not found.")

        # classes
        self.classes = ['crease', 'crescent_gap', 'silk_spot', 'water_spot',
                        'welding_line', 'inclusion', 'oil_spot',
                        'waist folding', 'rolled_pit', 'punching_hole']

    def __getitem__(self, idx):
      img_name = self.imgs[idx]
      image_path = img_name

      # Read the image
      img = cv2.imread(image_path)
      img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
      img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
      img_res /= 255.0

      # Extract annotation filename from image name
      annot_filename = os.path.splitext(os.path.basename(img_name))[0] + '.xml'
      annot_file_path = os.path.join(self.annotation_dir, annot_filename)

      boxes = []
      labels = []
      tree = et.parse(annot_file_path)
      root = tree.getroot()

      # cv2 image gives size as height x width
      wt = img.shape[1]
      ht = img.shape[0]

      # Get the folder name to determine the label
      folder_name = os.path.basename(os.path.dirname(img_name))

      # Ensure the folder name corresponds to a class
      if folder_name in self.classes:
        folder_label = self.classes.index(folder_name)
      else:
        raise ValueError(f'Folder name {folder_name} not recognized as a valid class.')

      # box coordinates for xml files are extracted and corrected for image size given
      for member in root.findall('object'):
          # bounding box
          xmin = int(member.find('bndbox').find('xmin').text)
          xmax = int(member.find('bndbox').find('xmax').text)
          ymin = int(member.find('bndbox').find('ymin').text)
          ymax = int(member.find('bndbox').find('ymax').text)

          # Scale bounding boxes to resized image dimensions
          xmin_corr = (xmin / wt) * self.width
          xmax_corr = (xmax / wt) * self.width
          ymin_corr = (ymin / ht) * self.height
          ymax_corr = (ymax / ht) * self.height

          if xmax_corr > xmin_corr + 1 and ymax_corr > ymin_corr + 1:
            boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
            labels.append(folder_label)
          else:
            print(f"Warning: Invalid box detected: [{xmin_corr}, {ymin_corr}, {xmax_corr}, {ymax_corr}]. Skipping.")

      # Convert boxes into a torch.Tensor
      boxes = torch.as_tensor(boxes, dtype=torch.float32)

      # Get areas of the boxes
      if boxes.dim() == 2:  # If boxes has 2 dimensions (rows and columns)
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
      else:  # If boxes is empty or 1-dimensional
        area = torch.tensor([], dtype=torch.float32)  # Create an empty tensor for area


      # Suppose all instances are not crowd
      iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)

      labels = torch.as_tensor(labels, dtype=torch.int64)

      target = {}
      target["boxes"] = boxes
      target["labels"] = labels
      target["area"] = area
      target["iscrowd"] = iscrowd

      # image_id
      # image_id = torch.tensor([idx])
      target["image_id"] = idx


      if self.transforms:
          # Apply transformations
          sample = self.transforms(image=img_res, bboxes=target['boxes'].tolist(),
                                   labels=target['labels'].numpy())
          img_res = sample['image']
          target['boxes'] = torch.Tensor(sample['bboxes'])

        # Convert img_res from [H, W, C] to [C, H, W] after transformation
        # img_res = img_res.permute(2, 0, 1)  # Convert to [C, H, W] for PyTorch

      return img_res, target

    def __len__(self):
        return len(self.imgs)

# %%
# Visualization
def plot_img_bbox(img, targets):
    index_to_class = {i: cls for i, cls in enumerate(['crescent_gap', 'crease', 'silk_spot', 'water_spot', 'welding_line', 'inclusion',
                                                      'oil_spot', 'waist folding','rolled_pit', 'punching_hole'])}

    # Define a mapping from index to class name
    fig, a = plt.subplots(1,1)
    fig.set_size_inches(5,5)
    a.imshow(img)

    class_names = []

    for box, label in zip(targets['boxes'], targets['labels']):
      x_min, y_min, x_max, y_max = box.cpu().numpy()  # Ensure box is on CPU for NumPy
      width, height = x_max - x_min, y_max - y_min

      # Create a rectangle patch
      rect = patches.Rectangle((x_min, y_min), width, height, linewidth=2, edgecolor='r', facecolor='none')
      a.add_patch(rect)

      # Add the class name to the title
      class_name = index_to_class[label.item()]
      class_names.append(class_name)

    title = ', '.join(set(class_names))
    plt.title(title, fontsize=12)
    plt.show()

# %%
# Call dataset without transforming
dataset = GC10Dataset(file_dir, annotation_dir, 224, 224)
print('length of dataset = ', len(dataset), '\n')

# Display a sample training image with its label
for img, target in dataset:
    print(img.shape, '\n',target)
    plot_img_bbox(img, target)
    # Break after showing one batch
    break
# Out:
# length of dataset =  2280
#
# (224, 224, 3)
#  {'boxes': tensor([[198.7344,  61.1520, 212.2969,  96.9920]]), 'labels': tensor([3]), 'area': tensor([486.0800]), 'iscrowd': tensor([0]), 'image_id': 0}

# %%
# Define a model "fasterrcnn_resnet50_fpn pretrained"

def get_object_detection_model(num_classes):
    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)

    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    return model

# %%
# Send train=True fro training transforms and False for val/test transforms
def get_transform(train):

    if train:
        return A.Compose([
                            A.HorizontalFlip(0.5),
                            A.VerticalFlip(0.5),
                            A.RandomBrightnessContrast(0.1),
                            A.ColorJitter(0.1),
                     # ToTensorV2 converts image to pytorch tensor without div by 255
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})
    else:
        return A.Compose([
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %%
# use our dataset and defined transformations
dataset = GC10Dataset(file_dir, annotation_dir, 224, 224, transforms= get_transform(train=True))
dataset_test = GC10Dataset(file_dir, annotation_dir, 224, 224, transforms= get_transform(train=False))

# split the dataset in train and test set
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()

# train test split
test_split = 0.2
tsize = int(len(dataset)*test_split)
dataset = torch.utils.data.Subset(dataset, indices[:-tsize])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-tsize:])

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=10, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=10, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %%
images, targets = next(iter(data_loader))
images = list(image for image in images)
images = torch.stack(images)
    # Ensure images are in the format [N, C, H, W]
print("Original images shape:", images.shape)  # Should be [N, C, H, W]
# Out:
# Original images shape: torch.Size([10, 3, 224, 224])

# %%
# to train on gpu if selected.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
num_classes = 10
# get the model using our helper function
model = get_object_detection_model(num_classes)
# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:01<00:00, 149MB/s]

# %%
# training for 20 epochs
num_epochs = 20

for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [  0/183]  eta: 0:31:37  lr: 0.000032  loss: 2.6494 (2.6494)  loss_classifier: 2.2358 (2.2358)  loss_box_reg: 0.0725 (0.0725)  loss_objectness: 0.2820 (0.2820)  loss_rpn_box_reg: 0.0591 (0.0591)  time: 10.3685  data: 5.3534  max mem: 8200
# Epoch: [0]  [ 10/183]  eta: 0:07:14  lr: 0.000307  loss: 2.2169 (2.0175)  loss_classifier: 1.7346 (1.5108)  loss_box_reg: 0.0778 (0.0848)  loss_objectness: 0.2992 (0.3615)  loss_rpn_box_reg: 0.0591 (0.0603)  time: 2.5135  data: 0.5119  max mem: 8360
# Epoch: [0]  [ 20/183]  eta: 0:05:52  lr: 0.000581  loss: 0.7112 (1.3128)  loss_classifier: 0.2584 (0.8724)  loss_box_reg: 0.0778 (0.0873)  loss_objectness: 0.2724 (0.2929)  loss_rpn_box_reg: 0.0541 (0.0602)  time: 1.7493  data: 0.0289  max mem: 8361
# Epoch: [0]  [ 30/183]  eta: 0:05:15  lr: 0.000856  loss: 0.4464 (1.0267)  loss_classifier: 0.1526 (0.6419)  loss_box_reg: 0.0897 (0.0876)  loss_objectness: 0.1577 (0.2322)  loss_rpn_box_reg: 0.0541 (0.0649)  time: 1.8094  data: 0.0353  max mem: 8361
# Epoch: [0]  [ 40/183]  eta: 0:04:50  lr: 0.001130  loss: 0.3705 (0.8726)  loss_classifier: 0.1640 (0.5292)  loss_box_reg: 0.1008 (0.0947)  loss_objectness: 0.0563 (0.1877)  loss_rpn_box_reg: 0.0459 (0.0611)  time: 1.8909  data: 0.0367  max mem: 8361
# Epoch: [0]  [ 50/183]  eta: 0:04:26  lr: 0.001405  loss: 0.3798 (0.7730)  loss_classifier: 0.1668 (0.4570)  loss_box_reg: 0.1081 (0.1002)  loss_objectness: 0.0425 (0.1584)  loss_rpn_box_reg: 0.0401 (0.0573)  time: 1.9227  data: 0.0298  max mem: 8361
# Epoch: [0]  [ 60/183]  eta: 0:04:03  lr: 0.001679  loss: 0.3662 (0.6976)  loss_classifier: 0.1499 (0.4047)  loss_box_reg: 0.1154 (0.1021)  loss_objectness: 0.0349 (0.1366)  loss_rpn_box_reg: 0.0355 (0.0542)  time: 1.8842  data: 0.0286  max mem: 8361
# Epoch: [0]  [ 70/183]  eta: 0:03:41  lr: 0.001954  loss: 0.3367 (0.6500)  loss_classifier: 0.1458 (0.3685)  loss_box_reg: 0.1197 (0.1071)  loss_objectness: 0.0182 (0.1206)  loss_rpn_box_reg: 0.0393 (0.0538)  time: 1.8498  data: 0.0309  max mem: 8361
# Epoch: [0]  [ 80/183]  eta: 0:03:20  lr: 0.002228  loss: 0.3496 (0.6166)  loss_classifier: 0.1474 (0.3427)  loss_box_reg: 0.1381 (0.1115)  loss_objectness: 0.0235 (0.1096)  loss_rpn_box_reg: 0.0414 (0.0528)  time: 1.8424  data: 0.0298  max mem: 8361
# Epoch: [0]  [ 90/183]  eta: 0:03:00  lr: 0.002502  loss: 0.3484 (0.5877)  loss_classifier: 0.1474 (0.3216)  loss_box_reg: 0.1335 (0.1142)  loss_objectness: 0.0238 (0.1006)  loss_rpn_box_reg: 0.0341 (0.0514)  time: 1.8529  data: 0.0283  max mem: 8361
# Epoch: [0]  [100/183]  eta: 0:02:40  lr: 0.002777  loss: 0.3488 (0.5650)  loss_classifier: 0.1460 (0.3050)  loss_box_reg: 0.1393 (0.1175)  loss_objectness: 0.0214 (0.0926)  loss_rpn_box_reg: 0.0313 (0.0498)  time: 1.8631  data: 0.0310  max mem: 8361
# Epoch: [0]  [110/183]  eta: 0:02:20  lr: 0.003051  loss: 0.3488 (0.5431)  loss_classifier: 0.1395 (0.2895)  loss_box_reg: 0.1393 (0.1186)  loss_objectness: 0.0175 (0.0872)  loss_rpn_box_reg: 0.0259 (0.0477)  time: 1.8529  data: 0.0304  max mem: 8361
# Epoch: [0]  [120/183]  eta: 0:02:00  lr: 0.003326  loss: 0.3309 (0.5284)  loss_classifier: 0.1375 (0.2777)  loss_box_reg: 0.1304 (0.1207)  loss_objectness: 0.0175 (0.0832)  loss_rpn_box_reg: 0.0271 (0.0467)  time: 1.8447  data: 0.0282  max mem: 8361
# Epoch: [0]  [130/183]  eta: 0:01:41  lr: 0.003600  loss: 0.3330 (0.5142)  loss_classifier: 0.1461 (0.2674)  loss_box_reg: 0.1428 (0.1228)  loss_objectness: 0.0200 (0.0784)  loss_rpn_box_reg: 0.0287 (0.0457)  time: 1.8516  data: 0.0311  max mem: 8361
# Epoch: [0]  [140/183]  eta: 0:01:22  lr: 0.003875  loss: 0.3044 (0.4987)  loss_classifier: 0.1266 (0.2572)  loss_box_reg: 0.1237 (0.1230)  loss_objectness: 0.0189 (0.0744)  loss_rpn_box_reg: 0.0234 (0.0441)  time: 1.8588  data: 0.0314  max mem: 8361
# Epoch: [0]  [150/183]  eta: 0:01:02  lr: 0.004149  loss: 0.3018 (0.4886)  loss_classifier: 0.1246 (0.2490)  loss_box_reg: 0.1268 (0.1240)  loss_objectness: 0.0194 (0.0717)  loss_rpn_box_reg: 0.0247 (0.0438)  time: 1.8584  data: 0.0295  max mem: 8361
# Epoch: [0]  [160/183]  eta: 0:00:43  lr: 0.004424  loss: 0.3442 (0.4798)  loss_classifier: 0.1309 (0.2423)  loss_box_reg: 0.1343 (0.1251)  loss_objectness: 0.0210 (0.0687)  loss_rpn_box_reg: 0.0328 (0.0437)  time: 1.8546  data: 0.0298  max mem: 8361
# Epoch: [0]  [170/183]  eta: 0:00:24  lr: 0.004698  loss: 0.3419 (0.4707)  loss_classifier: 0.1241 (0.2352)  loss_box_reg: 0.1371 (0.1258)  loss_objectness: 0.0162 (0.0660)  loss_rpn_box_reg: 0.0341 (0.0437)  time: 1.8520  data: 0.0317  max mem: 8361
# Epoch: [0]  [180/183]  eta: 0:00:05  lr: 0.004973  loss: 0.3091 (0.4597)  loss_classifier: 0.1067 (0.2277)  loss_box_reg: 0.1191 (0.1248)  loss_objectness: 0.0162 (0.0634)  loss_rpn_box_reg: 0.0341 (0.0439)  time: 1.8491  data: 0.0291  max mem: 8361
# Epoch: [0]  [182/183]  eta: 0:00:01  lr: 0.005000  loss: 0.2699 (0.4572)  loss_classifier: 0.0998 (0.2262)  loss_box_reg: 0.1165 (0.1246)  loss_objectness: 0.0160 (0.0629)  loss_rpn_box_reg: 0.0339 (0.0435)  time: 1.7991  data: 0.0283  max mem: 8361
# Epoch: [0] Total time: 0:05:45 (1.8902 s / it)
# creating index...
# index created!
# Test:  [ 0/46]  eta: 0:01:37  model_time: 1.1133 (1.1133)  evaluator_time: 0.0282 (0.0282)  time: 2.1280  data: 0.9779  max mem: 8361
# Test:  [45/46]  eta: 0:00:00  model_time: 0.8257 (0.9150)  evaluator_time: 0.0162 (0.0290)  time: 0.8690  data: 0.0242  max mem: 8361
# Test: Total time: 0:00:45 (0.9969 s / it)
# Averaged stats: model_time: 0.8257 (0.9150)  evaluator_time: 0.0162 (0.0290)
# Accumulating evaluation results...
# DONE (t=0.33s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.112
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.265
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.157
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.243
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.222
# Epoch: [1]  [  0/183]  eta: 0:09:36  lr: 0.005000  loss: 0.2448 (0.2448)  loss_classifier: 0.0955 (0.0955)  loss_box_reg: 0.1059 (0.1059)  loss_objectness: 0.0194 (0.0194)  loss_rpn_box_reg: 0.0239 (0.0239)  time: 3.1481  data: 1.1152  max mem: 8361
# Epoch: [1]  [ 10/183]  eta: 0:05:34  lr: 0.005000  loss: 0.2771 (0.2887)  loss_classifier: 0.0977 (0.1053)  loss_box_reg: 0.1096 (0.1161)  loss_objectness: 0.0194 (0.0232)  loss_rpn_box_reg: 0.0420 (0.0441)  time: 1.9319  data: 0.1250  max mem: 8361
# Epoch: [1]  [ 20/183]  eta: 0:05:06  lr: 0.005000  loss: 0.2771 (0.3008)  loss_classifier: 0.1074 (0.1116)  loss_box_reg: 0.1138 (0.1222)  loss_objectness: 0.0157 (0.0239)  loss_rpn_box_reg: 0.0398 (0.0431)  time: 1.8195  data: 0.0263  max mem: 8361
# Epoch: [1]  [ 30/183]  eta: 0:04:47  lr: 0.005000  loss: 0.2732 (0.2952)  loss_classifier: 0.1074 (0.1125)  loss_box_reg: 0.1126 (0.1214)  loss_objectness: 0.0157 (0.0217)  loss_rpn_box_reg: 0.0242 (0.0397)  time: 1.8505  data: 0.0287  max mem: 8361
# Epoch: [1]  [ 40/183]  eta: 0:04:27  lr: 0.005000  loss: 0.2826 (0.3004)  loss_classifier: 0.1100 (0.1161)  loss_box_reg: 0.1095 (0.1229)  loss_objectness: 0.0163 (0.0218)  loss_rpn_box_reg: 0.0267 (0.0396)  time: 1.8574  data: 0.0297  max mem: 8361
# Epoch: [1]  [ 50/183]  eta: 0:04:07  lr: 0.005000  loss: 0.2634 (0.2928)  loss_classifier: 0.1024 (0.1141)  loss_box_reg: 0.1072 (0.1198)  loss_objectness: 0.0137 (0.0206)  loss_rpn_box_reg: 0.0267 (0.0383)  time: 1.8413  data: 0.0283  max mem: 8361
# Epoch: [1]  [ 60/183]  eta: 0:03:48  lr: 0.005000  loss: 0.2340 (0.2949)  loss_classifier: 0.1013 (0.1140)  loss_box_reg: 0.1077 (0.1198)  loss_objectness: 0.0156 (0.0224)  loss_rpn_box_reg: 0.0276 (0.0388)  time: 1.8366  data: 0.0284  max mem: 8361
# Epoch: [1]  [ 70/183]  eta: 0:03:30  lr: 0.005000  loss: 0.2730 (0.2941)  loss_classifier: 0.1138 (0.1147)  loss_box_reg: 0.1149 (0.1184)  loss_objectness: 0.0198 (0.0227)  loss_rpn_box_reg: 0.0276 (0.0383)  time: 1.8436  data: 0.0280  max mem: 8361
# Epoch: [1]  [ 80/183]  eta: 0:03:11  lr: 0.005000  loss: 0.2615 (0.2895)  loss_classifier: 0.0944 (0.1137)  loss_box_reg: 0.1107 (0.1171)  loss_objectness: 0.0142 (0.0219)  loss_rpn_box_reg: 0.0241 (0.0367)  time: 1.8518  data: 0.0268  max mem: 8361
# Epoch: [1]  [ 90/183]  eta: 0:02:52  lr: 0.005000  loss: 0.2438 (0.2855)  loss_classifier: 0.0862 (0.1103)  loss_box_reg: 0.0960 (0.1144)  loss_objectness: 0.0185 (0.0232)  loss_rpn_box_reg: 0.0304 (0.0376)  time: 1.8505  data: 0.0283  max mem: 8361
# Epoch: [1]  [100/183]  eta: 0:02:34  lr: 0.005000  loss: 0.2578 (0.2871)  loss_classifier: 0.0853 (0.1115)  loss_box_reg: 0.0960 (0.1147)  loss_objectness: 0.0229 (0.0233)  loss_rpn_box_reg: 0.0349 (0.0376)  time: 1.8485  data: 0.0294  max mem: 8361
# Epoch: [1]  [110/183]  eta: 0:02:15  lr: 0.005000  loss: 0.2483 (0.2843)  loss_classifier: 0.0947 (0.1102)  loss_box_reg: 0.1045 (0.1144)  loss_objectness: 0.0174 (0.0226)  loss_rpn_box_reg: 0.0316 (0.0372)  time: 1.8352  data: 0.0274  max mem: 8361
# Epoch: [1]  [120/183]  eta: 0:01:56  lr: 0.005000  loss: 0.2430 (0.2827)  loss_classifier: 0.0938 (0.1104)  loss_box_reg: 0.1089 (0.1140)  loss_objectness: 0.0141 (0.0220)  loss_rpn_box_reg: 0.0241 (0.0363)  time: 1.8262  data: 0.0269  max mem: 8361
# Epoch: [1]  [130/183]  eta: 0:01:38  lr: 0.005000  loss: 0.2530 (0.2811)  loss_classifier: 0.1023 (0.1094)  loss_box_reg: 0.1137 (0.1136)  loss_objectness: 0.0144 (0.0217)  loss_rpn_box_reg: 0.0245 (0.0364)  time: 1.8327  data: 0.0273  max mem: 8361
# Epoch: [1]  [140/183]  eta: 0:01:19  lr: 0.005000  loss: 0.2499 (0.2776)  loss_classifier: 0.0928 (0.1080)  loss_box_reg: 0.0968 (0.1124)  loss_objectness: 0.0144 (0.0212)  loss_rpn_box_reg: 0.0262 (0.0360)  time: 1.8406  data: 0.0276  max mem: 8361
# Epoch: [1]  [150/183]  eta: 0:01:01  lr: 0.005000  loss: 0.2269 (0.2759)  loss_classifier: 0.0928 (0.1075)  loss_box_reg: 0.0924 (0.1118)  loss_objectness: 0.0154 (0.0212)  loss_rpn_box_reg: 0.0252 (0.0354)  time: 1.8505  data: 0.0272  max mem: 8361
# Epoch: [1]  [160/183]  eta: 0:00:42  lr: 0.005000  loss: 0.2634 (0.2762)  loss_classifier: 0.1045 (0.1079)  loss_box_reg: 0.1136 (0.1122)  loss_objectness: 0.0185 (0.0209)  loss_rpn_box_reg: 0.0264 (0.0352)  time: 1.8466  data: 0.0272  max mem: 8361
# Epoch: [1]  [170/183]  eta: 0:00:24  lr: 0.005000  loss: 0.2600 (0.2755)  loss_classifier: 0.1018 (0.1077)  loss_box_reg: 0.1059 (0.1119)  loss_objectness: 0.0153 (0.0206)  loss_rpn_box_reg: 0.0256 (0.0353)  time: 1.8417  data: 0.0276  max mem: 8361
# Epoch: [1]  [180/183]  eta: 0:00:05  lr: 0.005000  loss: 0.2664 (0.2754)  loss_classifier: 0.0929 (0.1072)  loss_box_reg: 0.1014 (0.1113)  loss_objectness: 0.0125 (0.0210)  loss_rpn_box_reg: 0.0276 (0.0360)  time: 1.8373  data: 0.0261  max mem: 8361
# Epoch: [1]  [182/183]  eta: 0:00:01  lr: 0.005000  loss: 0.2664 (0.2751)  loss_classifier: 0.0929 (0.1070)  loss_box_reg: 0.1014 (0.1113)  loss_objectness: 0.0125 (0.0210)  loss_rpn_box_reg: 0.0249 (0.0358)  time: 1.7807  data: 0.0248  max mem: 8361
# Epoch: [1] Total time: 0:05:37 (1.8423 s / it)
# creating index...
# index created!
# Test:  [ 0/46]  eta: 0:02:27  model_time: 1.1738 (1.1738)  evaluator_time: 0.1053 (0.1053)  time: 3.2009  data: 1.9100  max mem: 8361
# Test:  [45/46]  eta: 0:00:00  model_time: 0.8390 (0.8375)  evaluator_time: 0.0158 (0.0225)  time: 0.8763  data: 0.0249  max mem: 8361
# Test: Total time: 0:00:42 (0.9319 s / it)
# Averaged stats: model_time: 0.8390 (0.8375)  evaluator_time: 0.0158 (0.0225)
# Accumulating evaluation results...
# DONE (t=0.30s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.408
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.130
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.161
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.354
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.363
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.338
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.302
# Epoch: [2]  [  0/183]  eta: 0:10:22  lr: 0.005000  loss: 0.2771 (0.2771)  loss_classifier: 0.1164 (0.1164)  loss_box_reg: 0.1283 (0.1283)  loss_objectness: 0.0220 (0.0220)  loss_rpn_box_reg: 0.0104 (0.0104)  time: 3.4001  data: 1.3941  max mem: 8361
# Epoch: [2]  [ 10/183]  eta: 0:05:42  lr: 0.005000  loss: 0.2645 (0.2608)  loss_classifier: 0.0951 (0.0976)  loss_box_reg: 0.1135 (0.1128)  loss_objectness: 0.0174 (0.0162)  loss_rpn_box_reg: 0.0314 (0.0341)  time: 1.9799  data: 0.1454  max mem: 8361
# Epoch: [2]  [ 20/183]  eta: 0:05:10  lr: 0.005000  loss: 0.2612 (0.2690)  loss_classifier: 0.0951 (0.1047)  loss_box_reg: 0.1050 (0.1129)  loss_objectness: 0.0111 (0.0140)  loss_rpn_box_reg: 0.0339 (0.0375)  time: 1.8284  data: 0.0229  max mem: 8361
# Epoch: [2]  [ 30/183]  eta: 0:04:47  lr: 0.005000  loss: 0.2429 (0.2663)  loss_classifier: 0.0929 (0.1046)  loss_box_reg: 0.0941 (0.1106)  loss_objectness: 0.0101 (0.0145)  loss_rpn_box_reg: 0.0331 (0.0366)  time: 1.8279  data: 0.0262  max mem: 8361
# Epoch: [2]  [ 40/183]  eta: 0:04:27  lr: 0.005000  loss: 0.2352 (0.2673)  loss_classifier: 0.0894 (0.1047)  loss_box_reg: 0.1036 (0.1119)  loss_objectness: 0.0101 (0.0146)  loss_rpn_box_reg: 0.0283 (0.0362)  time: 1.8408  data: 0.0280  max mem: 8361
# Epoch: [2]  [ 50/183]  eta: 0:04:08  lr: 0.005000  loss: 0.2515 (0.2666)  loss_classifier: 0.0946 (0.1037)  loss_box_reg: 0.1031 (0.1116)  loss_objectness: 0.0155 (0.0166)  loss_rpn_box_reg: 0.0278 (0.0347)  time: 1.8526  data: 0.0272  max mem: 8361
# Epoch: [2]  [ 60/183]  eta: 0:03:49  lr: 0.005000  loss: 0.2515 (0.2638)  loss_classifier: 0.0895 (0.1018)  loss_box_reg: 0.0966 (0.1108)  loss_objectness: 0.0157 (0.0166)  loss_rpn_box_reg: 0.0247 (0.0346)  time: 1.8544  data: 0.0253  max mem: 8361
# Epoch: [2]  [ 70/183]  eta: 0:03:30  lr: 0.005000  loss: 0.2285 (0.2591)  loss_classifier: 0.0839 (0.0997)  loss_box_reg: 0.0924 (0.1086)  loss_objectness: 0.0126 (0.0166)  loss_rpn_box_reg: 0.0253 (0.0341)  time: 1.8431  data: 0.0256  max mem: 8361
# Epoch: [2]  [ 80/183]  eta: 0:03:11  lr: 0.005000  loss: 0.2341 (0.2584)  loss_classifier: 0.0900 (0.0993)  loss_box_reg: 0.1041 (0.1081)  loss_objectness: 0.0127 (0.0164)  loss_rpn_box_reg: 0.0256 (0.0346)  time: 1.8366  data: 0.0268  max mem: 8361
# Epoch: [2]  [ 90/183]  eta: 0:02:52  lr: 0.005000  loss: 0.2293 (0.2516)  loss_classifier: 0.0729 (0.0958)  loss_box_reg: 0.0899 (0.1047)  loss_objectness: 0.0127 (0.0161)  loss_rpn_box_reg: 0.0332 (0.0350)  time: 1.8419  data: 0.0272  max mem: 8361
# Epoch: [2]  [100/183]  eta: 0:02:34  lr: 0.005000  loss: 0.2060 (0.2521)  loss_classifier: 0.0729 (0.0952)  loss_box_reg: 0.0899 (0.1053)  loss_objectness: 0.0147 (0.0161)  loss_rpn_box_reg: 0.0332 (0.0356)  time: 1.8475  data: 0.0276  max mem: 8361
# Epoch: [2]  [110/183]  eta: 0:02:15  lr: 0.005000  loss: 0.2372 (0.2523)  loss_classifier: 0.0860 (0.0950)  loss_box_reg: 0.1025 (0.1058)  loss_objectness: 0.0133 (0.0164)  loss_rpn_box_reg: 0.0318 (0.0351)  time: 1.8438  data: 0.0273  max mem: 8361
# Epoch: [2]  [120/183]  eta: 0:01:56  lr: 0.005000  loss: 0.2372 (0.2511)  loss_classifier: 0.0886 (0.0951)  loss_box_reg: 0.0973 (0.1054)  loss_objectness: 0.0114 (0.0160)  loss_rpn_box_reg: 0.0238 (0.0346)  time: 1.8371  data: 0.0277  max mem: 8361
# Epoch: [2]  [130/183]  eta: 0:01:38  lr: 0.005000  loss: 0.2253 (0.2504)  loss_classifier: 0.0851 (0.0949)  loss_box_reg: 0.0955 (0.1045)  loss_objectness: 0.0084 (0.0158)  loss_rpn_box_reg: 0.0254 (0.0353)  time: 1.8359  data: 0.0297  max mem: 8361
# Epoch: [2]  [140/183]  eta: 0:01:19  lr: 0.005000  loss: 0.2264 (0.2496)  loss_classifier: 0.0869 (0.0946)  loss_box_reg: 0.0963 (0.1043)  loss_objectness: 0.0084 (0.0157)  loss_rpn_box_reg: 0.0330 (0.0351)  time: 1.8362  data: 0.0291  max mem: 8361
# Epoch: [2]  [150/183]  eta: 0:01:01  lr: 0.005000  loss: 0.2013 (0.2467)  loss_classifier: 0.0809 (0.0935)  loss_box_reg: 0.0920 (0.1034)  loss_objectness: 0.0121 (0.0155)  loss_rpn_box_reg: 0.0260 (0.0343)  time: 1.8400  data: 0.0274  max mem: 8361
# Epoch: [2]  [160/183]  eta: 0:00:42  lr: 0.005000  loss: 0.2149 (0.2491)  loss_classifier: 0.0807 (0.0949)  loss_box_reg: 0.0921 (0.1040)  loss_objectness: 0.0122 (0.0156)  loss_rpn_box_reg: 0.0260 (0.0347)  time: 1.8522  data: 0.0285  max mem: 8361
# Epoch: [2]  [170/183]  eta: 0:00:24  lr: 0.005000  loss: 0.2559 (0.2486)  loss_classifier: 0.0903 (0.0945)  loss_box_reg: 0.0996 (0.1037)  loss_objectness: 0.0129 (0.0156)  loss_rpn_box_reg: 0.0285 (0.0347)  time: 1.8448  data: 0.0293  max mem: 8361
# Epoch: [2]  [180/183]  eta: 0:00:05  lr: 0.005000  loss: 0.2199 (0.2479)  loss_classifier: 0.0829 (0.0944)  loss_box_reg: 0.0966 (0.1039)  loss_objectness: 0.0119 (0.0154)  loss_rpn_box_reg: 0.0258 (0.0342)  time: 1.8285  data: 0.0269  max mem: 8361
# Epoch: [2]  [182/183]  eta: 0:00:01  lr: 0.005000  loss: 0.2199 (0.2472)  loss_classifier: 0.0787 (0.0939)  loss_box_reg: 0.0961 (0.1036)  loss_objectness: 0.0121 (0.0154)  loss_rpn_box_reg: 0.0248 (0.0344)  time: 1.7746  data: 0.0262  max mem: 8361
# Epoch: [2] Total time: 0:05:37 (1.8432 s / it)
# creating index...
# index created!
# Test:  [ 0/46]  eta: 0:01:34  model_time: 0.9507 (0.9507)  evaluator_time: 0.0217 (0.0217)  time: 2.0568  data: 1.0806  max mem: 8361
# Test:  [45/46]  eta: 0:00:00  model_time: 0.8343 (0.8371)  evaluator_time: 0.0146 (0.0150)  time: 0.8674  data: 0.0250  max mem: 8361
# Test: Total time: 0:00:42 (0.9142 s / it)
# Averaged stats: model_time: 0.8343 (0.8371)  evaluator_time: 0.0146 (0.0150)
# Accumulating evaluation results...
# DONE (t=0.34s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.219
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.464
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.218
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.247
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.385
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.376
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.321
# Epoch: [3]  [  0/183]  eta: 0:12:31  lr: 0.000500  loss: 0.2003 (0.2003)  loss_classifier: 0.0589 (0.0589)  loss_box_reg: 0.0652 (0.0652)  loss_objectness: 0.0095 (0.0095)  loss_rpn_box_reg: 0.0667 (0.0667)  time: 4.1046  data: 1.6721  max mem: 8361
# Epoch: [3]  [ 10/183]  eta: 0:05:52  lr: 0.000500  loss: 0.2335 (0.2366)  loss_classifier: 0.0871 (0.0907)  loss_box_reg: 0.0976 (0.1005)  loss_objectness: 0.0095 (0.0099)  loss_rpn_box_reg: 0.0322 (0.0355)  time: 2.0355  data: 0.1855  max mem: 8361
# Epoch: [3]  [ 20/183]  eta: 0:05:14  lr: 0.000500  loss: 0.2366 (0.2453)  loss_classifier: 0.0852 (0.0928)  loss_box_reg: 0.0989 (0.1021)  loss_objectness: 0.0102 (0.0179)  loss_rpn_box_reg: 0.0234 (0.0325)  time: 1.8221  data: 0.0313  max mem: 8361
# Epoch: [3]  [ 30/183]  eta: 0:04:50  lr: 0.000500  loss: 0.2294 (0.2365)  loss_classifier: 0.0800 (0.0873)  loss_box_reg: 0.0962 (0.0973)  loss_objectness: 0.0124 (0.0171)  loss_rpn_box_reg: 0.0239 (0.0348)  time: 1.8242  data: 0.0272  max mem: 8361
# Epoch: [3]  [ 40/183]  eta: 0:04:29  lr: 0.000500  loss: 0.2154 (0.2396)  loss_classifier: 0.0838 (0.0901)  loss_box_reg: 0.0849 (0.0983)  loss_objectness: 0.0130 (0.0172)  loss_rpn_box_reg: 0.0239 (0.0340)  time: 1.8418  data: 0.0283  max mem: 8361
# Epoch: [3]  [ 50/183]  eta: 0:04:09  lr: 0.000500  loss: 0.2224 (0.2396)  loss_classifier: 0.0838 (0.0913)  loss_box_reg: 0.0888 (0.0996)  loss_objectness: 0.0112 (0.0160)  loss_rpn_box_reg: 0.0253 (0.0327)  time: 1.8458  data: 0.0275  max mem: 8361
# Epoch: [3]  [ 60/183]  eta: 0:03:50  lr: 0.000500  loss: 0.2224 (0.2376)  loss_classifier: 0.0836 (0.0907)  loss_box_reg: 0.0964 (0.0994)  loss_objectness: 0.0111 (0.0153)  loss_rpn_box_reg: 0.0263 (0.0322)  time: 1.8410  data: 0.0284  max mem: 8361
# Epoch: [3]  [ 70/183]  eta: 0:03:31  lr: 0.000500  loss: 0.2287 (0.2372)  loss_classifier: 0.0833 (0.0902)  loss_box_reg: 0.0957 (0.0994)  loss_objectness: 0.0105 (0.0162)  loss_rpn_box_reg: 0.0206 (0.0314)  time: 1.8400  data: 0.0299  max mem: 8361
# Epoch: [3]  [ 80/183]  eta: 0:03:11  lr: 0.000500  loss: 0.2262 (0.2376)  loss_classifier: 0.0833 (0.0904)  loss_box_reg: 0.0941 (0.1004)  loss_objectness: 0.0105 (0.0158)  loss_rpn_box_reg: 0.0215 (0.0309)  time: 1.8367  data: 0.0287  max mem: 8361
# Epoch: [3]  [ 90/183]  eta: 0:02:53  lr: 0.000500  loss: 0.2036 (0.2366)  loss_classifier: 0.0804 (0.0900)  loss_box_reg: 0.0955 (0.1003)  loss_objectness: 0.0108 (0.0154)  loss_rpn_box_reg: 0.0270 (0.0308)  time: 1.8378  data: 0.0277  max mem: 8361
# Epoch: [3]  [100/183]  eta: 0:02:34  lr: 0.000500  loss: 0.2239 (0.2361)  loss_classifier: 0.0774 (0.0896)  loss_box_reg: 0.0955 (0.1006)  loss_objectness: 0.0122 (0.0152)  loss_rpn_box_reg: 0.0268 (0.0307)  time: 1.8449  data: 0.0269  max mem: 8361
# Epoch: [3]  [110/183]  eta: 0:02:15  lr: 0.000500  loss: 0.2266 (0.2347)  loss_classifier: 0.0780 (0.0897)  loss_box_reg: 0.0933 (0.1003)  loss_objectness: 0.0090 (0.0147)  loss_rpn_box_reg: 0.0268 (0.0301)  time: 1.8419  data: 0.0262  max mem: 8361
# Epoch: [3]  [120/183]  eta: 0:01:56  lr: 0.000500  loss: 0.2064 (0.2325)  loss_classifier: 0.0851 (0.0889)  loss_box_reg: 0.0893 (0.0996)  loss_objectness: 0.0084 (0.0142)  loss_rpn_box_reg: 0.0256 (0.0299)  time: 1.8325  data: 0.0275  max mem: 8361
# Epoch: [3]  [130/183]  eta: 0:01:38  lr: 0.000500  loss: 0.2030 (0.2299)  loss_classifier: 0.0788 (0.0883)  loss_box_reg: 0.0872 (0.0989)  loss_objectness: 0.0086 (0.0139)  loss_rpn_box_reg: 0.0190 (0.0288)  time: 1.8402  data: 0.0284  max mem: 8361
# Epoch: [3]  [140/183]  eta: 0:01:19  lr: 0.000500  loss: 0.2147 (0.2314)  loss_classifier: 0.0817 (0.0889)  loss_box_reg: 0.0921 (0.0999)  loss_objectness: 0.0108 (0.0140)  loss_rpn_box_reg: 0.0188 (0.0287)  time: 1.8470  data: 0.0278  max mem: 8361
# Epoch: [3]  [150/183]  eta: 0:01:01  lr: 0.000500  loss: 0.2254 (0.2303)  loss_classifier: 0.0817 (0.0881)  loss_box_reg: 0.1019 (0.0996)  loss_objectness: 0.0086 (0.0137)  loss_rpn_box_reg: 0.0257 (0.0290)  time: 1.8445  data: 0.0279  max mem: 8361
# Epoch: [3]  [160/183]  eta: 0:00:42  lr: 0.000500  loss: 0.2115 (0.2298)  loss_classifier: 0.0780 (0.0879)  loss_box_reg: 0.0878 (0.0993)  loss_objectness: 0.0087 (0.0135)  loss_rpn_box_reg: 0.0257 (0.0291)  time: 1.8438  data: 0.0267  max mem: 8361
# Epoch: [3]  [170/183]  eta: 0:00:24  lr: 0.000500  loss: 0.1933 (0.2292)  loss_classifier: 0.0740 (0.0871)  loss_box_reg: 0.0883 (0.0994)  loss_objectness: 0.0093 (0.0134)  loss_rpn_box_reg: 0.0323 (0.0293)  time: 1.8389  data: 0.0255  max mem: 8361
# Epoch: [3]  [180/183]  eta: 0:00:05  lr: 0.000500  loss: 0.2081 (0.2284)  loss_classifier: 0.0741 (0.0868)  loss_box_reg: 0.0934 (0.0995)  loss_objectness: 0.0101 (0.0132)  loss_rpn_box_reg: 0.0200 (0.0289)  time: 1.8366  data: 0.0258  max mem: 8361
# Epoch: [3]  [182/183]  eta: 0:00:01  lr: 0.000500  loss: 0.1849 (0.2276)  loss_classifier: 0.0676 (0.0864)  loss_box_reg: 0.0883 (0.0992)  loss_objectness: 0.0076 (0.0131)  loss_rpn_box_reg: 0.0200 (0.0288)  time: 1.7833  data: 0.0254  max mem: 8361
# Epoch: [3] Total time: 0:05:37 (1.8456 s / it)
# creating index...
# index created!
# Test:  [ 0/46]  eta: 0:01:39  model_time: 0.8815 (0.8815)  evaluator_time: 0.0218 (0.0218)  time: 2.1609  data: 1.2426  max mem: 8361
# Test:  [45/46]  eta: 0:00:00  model_time: 0.8416 (0.8370)  evaluator_time: 0.0147 (0.0168)  time: 0.8709  data: 0.0245  max mem: 8361
# Test: Total time: 0:00:41 (0.9110 s / it)
# Averaged stats: model_time: 0.8416 (0.8370)  evaluator_time: 0.0147 (0.0168)
# Accumulating evaluation results...
# DONE (t=0.28s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.242
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.492
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.234
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.402
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.411
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.404
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.319
# Epoch: [4]  [  0/183]  eta: 0:10:00  lr: 0.000500  loss: 0.3703 (0.3703)  loss_classifier: 0.1392 (0.1392)  loss_box_reg: 0.1987 (0.1987)  loss_objectness: 0.0224 (0.0224)  loss_rpn_box_reg: 0.0099 (0.0099)  time: 3.2791  data: 1.2273  max mem: 8361
# Epoch: [4]  [ 10/183]  eta: 0:05:35  lr: 0.000500  loss: 0.2151 (0.2320)  loss_classifier: 0.0750 (0.0801)  loss_box_reg: 0.1024 (0.1052)  loss_objectness: 0.0077 (0.0113)  loss_rpn_box_reg: 0.0293 (0.0354)  time: 1.9389  data: 0.1380  max mem: 8361
# Epoch: [4]  [ 20/183]  eta: 0:05:05  lr: 0.000500  loss: 0.2025 (0.2283)  loss_classifier: 0.0681 (0.0812)  loss_box_reg: 0.0961 (0.1037)  loss_objectness: 0.0090 (0.0114)  loss_rpn_box_reg: 0.0291 (0.0320)  time: 1.8020  data: 0.0276  max mem: 8528
# Epoch: [4]  [ 30/183]  eta: 0:04:44  lr: 0.000500  loss: 0.1937 (0.2197)  loss_classifier: 0.0681 (0.0808)  loss_box_reg: 0.0890 (0.1007)  loss_objectness: 0.0111 (0.0109)  loss_rpn_box_reg: 0.0201 (0.0273)  time: 1.8164  data: 0.0262  max mem: 8528
# Epoch: [4]  [ 40/183]  eta: 0:04:25  lr: 0.000500  loss: 0.2031 (0.2231)  loss_classifier: 0.0659 (0.0821)  loss_box_reg: 0.0850 (0.1011)  loss_objectness: 0.0086 (0.0107)  loss_rpn_box_reg: 0.0212 (0.0292)  time: 1.8431  data: 0.0281  max mem: 8528
# Epoch: [4]  [ 50/183]  eta: 0:04:07  lr: 0.000500  loss: 0.2017 (0.2200)  loss_classifier: 0.0801 (0.0820)  loss_box_reg: 0.0921 (0.0996)  loss_objectness: 0.0082 (0.0101)  loss_rpn_box_reg: 0.0268 (0.0284)  time: 1.8536  data: 0.0291  max mem: 8528
# Epoch: [4]  [ 60/183]  eta: 0:03:48  lr: 0.000500  loss: 0.2095 (0.2178)  loss_classifier: 0.0821 (0.0818)  loss_box_reg: 0.0926 (0.0979)  loss_objectness: 0.0083 (0.0100)  loss_rpn_box_reg: 0.0234 (0.0280)  time: 1.8502  data: 0.0290  max mem: 8528
# Epoch: [4]  [ 70/183]  eta: 0:03:29  lr: 0.000500  loss: 0.2113 (0.2159)  loss_classifier: 0.0821 (0.0809)  loss_box_reg: 0.0858 (0.0969)  loss_objectness: 0.0097 (0.0100)  loss_rpn_box_reg: 0.0223 (0.0281)  time: 1.8345  data: 0.0285  max mem: 8528
# Epoch: [4]  [ 80/183]  eta: 0:03:10  lr: 0.000500  loss: 0.2076 (0.2181)  loss_classifier: 0.0775 (0.0821)  loss_box_reg: 0.0980 (0.0984)  loss_objectness: 0.0084 (0.0098)  loss_rpn_box_reg: 0.0223 (0.0277)  time: 1.8224  data: 0.0277  max mem: 8528
# Epoch: [4]  [ 90/183]  eta: 0:02:51  lr: 0.000500  loss: 0.2171 (0.2234)  loss_classifier: 0.0832 (0.0846)  loss_box_reg: 0.0994 (0.1007)  loss_objectness: 0.0102 (0.0103)  loss_rpn_box_reg: 0.0253 (0.0278)  time: 1.8287  data: 0.0266  max mem: 8528
# Epoch: [4]  [100/183]  eta: 0:02:33  lr: 0.000500  loss: 0.2171 (0.2237)  loss_classifier: 0.0784 (0.0844)  loss_box_reg: 0.0962 (0.1000)  loss_objectness: 0.0107 (0.0114)  loss_rpn_box_reg: 0.0248 (0.0279)  time: 1.8421  data: 0.0255  max mem: 8528
# Epoch: [4]  [110/183]  eta: 0:02:14  lr: 0.000500  loss: 0.2219 (0.2263)  loss_classifier: 0.0781 (0.0855)  loss_box_reg: 0.0995 (0.1013)  loss_objectness: 0.0090 (0.0112)  loss_rpn_box_reg: 0.0301 (0.0283)  time: 1.8456  data: 0.0258  max mem: 8528
# Epoch: [4]  [120/183]  eta: 0:01:56  lr: 0.000500  loss: 0.2136 (0.2244)  loss_classifier: 0.0772 (0.0850)  loss_box_reg: 0.1028 (0.1007)  loss_objectness: 0.0083 (0.0112)  loss_rpn_box_reg: 0.0188 (0.0275)  time: 1.8386  data: 0.0260  max mem: 8528
# Epoch: [4]  [130/183]  eta: 0:01:37  lr: 0.000500  loss: 0.1996 (0.2245)  loss_classifier: 0.0803 (0.0850)  loss_box_reg: 0.0957 (0.1004)  loss_objectness: 0.0107 (0.0115)  loss_rpn_box_reg: 0.0188 (0.0275)  time: 1.8370  data: 0.0259  max mem: 8528
# Epoch: [4]  [140/183]  eta: 0:01:19  lr: 0.000500  loss: 0.2034 (0.2228)  loss_classifier: 0.0837 (0.0847)  loss_box_reg: 0.0850 (0.0994)  loss_objectness: 0.0119 (0.0116)  loss_rpn_box_reg: 0.0256 (0.0271)  time: 1.8354  data: 0.0261  max mem: 8528
# Epoch: [4]  [150/183]  eta: 0:01:00  lr: 0.000500  loss: 0.2034 (0.2222)  loss_classifier: 0.0858 (0.0846)  loss_box_reg: 0.0814 (0.0989)  loss_objectness: 0.0101 (0.0115)  loss_rpn_box_reg: 0.0172 (0.0272)  time: 1.8347  data: 0.0272  max mem: 8528
# Epoch: [4]  [160/183]  eta: 0:00:42  lr: 0.000500  loss: 0.2198 (0.2230)  loss_classifier: 0.0855 (0.0848)  loss_box_reg: 0.0943 (0.0990)  loss_objectness: 0.0085 (0.0116)  loss_rpn_box_reg: 0.0238 (0.0276)  time: 1.8379  data: 0.0275  max mem: 8528
# Epoch: [4]  [170/183]  eta: 0:00:23  lr: 0.000500  loss: 0.2165 (0.2236)  loss_classifier: 0.0830 (0.0851)  loss_box_reg: 0.0957 (0.0996)  loss_objectness: 0.0078 (0.0114)  loss_rpn_box_reg: 0.0243 (0.0275)  time: 1.8442  data: 0.0275  max mem: 8528
# Epoch: [4]  [180/183]  eta: 0:00:05  lr: 0.000500  loss: 0.2125 (0.2231)  loss_classifier: 0.0772 (0.0850)  loss_box_reg: 0.0979 (0.0992)  loss_objectness: 0.0078 (0.0113)  loss_rpn_box_reg: 0.0260 (0.0276)  time: 1.8377  data: 0.0269  max mem: 8528
# Epoch: [4]  [182/183]  eta: 0:00:01  lr: 0.000500  loss: 0.2125 (0.2233)  loss_classifier: 0.0772 (0.0851)  loss_box_reg: 0.0957 (0.0990)  loss_objectness: 0.0082 (0.0113)  loss_rpn_box_reg: 0.0260 (0.0278)  time: 1.7740  data: 0.0258  max mem: 8528
# Epoch: [4] Total time: 0:05:36 (1.8367 s / it)
# creating index...
# index created!
# Test:  [ 0/46]  eta: 0:02:14  model_time: 1.1308 (1.1308)  evaluator_time: 0.0611 (0.0611)  time: 2.9230  data: 1.7175  max mem: 8528
# Test:  [45/46]  eta: 0:00:00  model_time: 0.8377 (0.8425)  evaluator_time: 0.0126 (0.0180)  time: 0.8854  data: 0.0376  max mem: 8528
# Test: Total time: 0:00:43 (0.9363 s / it)
# Averaged stats: model_time: 0.8377 (0.8425)  evaluator_time: 0.0126 (0.0180)
# Accumulating evaluation results...
# DONE (t=0.22s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.243
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.492
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.262
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.417
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.326
# Epoch: [5]  [  0/183]  eta: 0:09:57  lr: 0.000500  loss: 0.1653 (0.1653)  loss_classifier: 0.0510 (0.0510)  loss_box_reg: 0.0661 (0.0661)  loss_objectness: 0.0090 (0.0090)  loss_rpn_box_reg: 0.0392 (0.0392)  time: 3.2638  data: 1.2009  max mem: 8528
# Epoch: [5]  [ 10/183]  eta: 0:05:38  lr: 0.000500  loss: 0.2228 (0.2373)  loss_classifier: 0.0945 (0.0934)  loss_box_reg: 0.0975 (0.1046)  loss_objectness: 0.0130 (0.0115)  loss_rpn_box_reg: 0.0194 (0.0279)  time: 1.9590  data: 0.1353  max mem: 8528
# Epoch: [5]  [ 20/183]  eta: 0:05:08  lr: 0.000500  loss: 0.2034 (0.2227)  loss_classifier: 0.0833 (0.0843)  loss_box_reg: 0.0915 (0.0965)  loss_objectness: 0.0075 (0.0104)  loss_rpn_box_reg: 0.0194 (0.0315)  time: 1.8239  data: 0.0282  max mem: 8528
# Epoch: [5]  [ 30/183]  eta: 0:04:47  lr: 0.000500  loss: 0.2030 (0.2226)  loss_classifier: 0.0677 (0.0845)  loss_box_reg: 0.1013 (0.0988)  loss_objectness: 0.0090 (0.0102)  loss_rpn_box_reg: 0.0217 (0.0292)  time: 1.8362  data: 0.0292  max mem: 8528
# Epoch: [5]  [ 40/183]  eta: 0:04:28  lr: 0.000500  loss: 0.2030 (0.2159)  loss_classifier: 0.0669 (0.0820)  loss_box_reg: 0.1013 (0.0958)  loss_objectness: 0.0093 (0.0104)  loss_rpn_box_reg: 0.0208 (0.0277)  time: 1.8569  data: 0.0302  max mem: 8528
# Epoch: [5]  [ 50/183]  eta: 0:04:08  lr: 0.000500  loss: 0.1991 (0.2144)  loss_classifier: 0.0669 (0.0813)  loss_box_reg: 0.0896 (0.0951)  loss_objectness: 0.0101 (0.0111)  loss_rpn_box_reg: 0.0196 (0.0269)  time: 1.8517  data: 0.0288  max mem: 8528
# Epoch: [5]  [ 60/183]  eta: 0:03:49  lr: 0.000500  loss: 0.2100 (0.2153)  loss_classifier: 0.0859 (0.0825)  loss_box_reg: 0.0910 (0.0950)  loss_objectness: 0.0115 (0.0110)  loss_rpn_box_reg: 0.0214 (0.0267)  time: 1.8386  data: 0.0279  max mem: 8528
# Epoch: [5]  [ 70/183]  eta: 0:03:30  lr: 0.000500  loss: 0.2132 (0.2176)  loss_classifier: 0.0841 (0.0829)  loss_box_reg: 0.0913 (0.0962)  loss_objectness: 0.0118 (0.0111)  loss_rpn_box_reg: 0.0256 (0.0274)  time: 1.8337  data: 0.0278  max mem: 8528
# Epoch: [5]  [ 80/183]  eta: 0:03:11  lr: 0.000500  loss: 0.2132 (0.2211)  loss_classifier: 0.0840 (0.0841)  loss_box_reg: 0.1002 (0.0978)  loss_objectness: 0.0112 (0.0111)  loss_rpn_box_reg: 0.0256 (0.0281)  time: 1.8464  data: 0.0284  max mem: 8528
# Epoch: [5]  [ 90/183]  eta: 0:02:53  lr: 0.000500  loss: 0.2559 (0.2228)  loss_classifier: 0.0958 (0.0847)  loss_box_reg: 0.0932 (0.0977)  loss_objectness: 0.0111 (0.0114)  loss_rpn_box_reg: 0.0261 (0.0290)  time: 1.8651  data: 0.0291  max mem: 8528
# Epoch: [5]  [100/183]  eta: 0:02:34  lr: 0.000500  loss: 0.2278 (0.2228)  loss_classifier: 0.0902 (0.0847)  loss_box_reg: 0.0932 (0.0978)  loss_objectness: 0.0114 (0.0117)  loss_rpn_box_reg: 0.0260 (0.0286)  time: 1.8531  data: 0.0289  max mem: 8528
# Epoch: [5]  [110/183]  eta: 0:02:15  lr: 0.000500  loss: 0.2111 (0.2221)  loss_classifier: 0.0783 (0.0844)  loss_box_reg: 0.0893 (0.0976)  loss_objectness: 0.0087 (0.0116)  loss_rpn_box_reg: 0.0222 (0.0285)  time: 1.8352  data: 0.0272  max mem: 8528
# Epoch: [5]  [120/183]  eta: 0:01:56  lr: 0.000500  loss: 0.2314 (0.2238)  loss_classifier: 0.0718 (0.0850)  loss_box_reg: 0.0952 (0.0989)  loss_objectness: 0.0087 (0.0116)  loss_rpn_box_reg: 0.0214 (0.0283)  time: 1.8451  data: 0.0265  max mem: 8528
# Epoch: [5]  [130/183]  eta: 0:01:38  lr: 0.000500  loss: 0.1996 (0.2212)  loss_classifier: 0.0694 (0.0836)  loss_box_reg: 0.0983 (0.0983)  loss_objectness: 0.0073 (0.0112)  loss_rpn_box_reg: 0.0241 (0.0280)  time: 1.8464  data: 0.0277  max mem: 8528
# Epoch: [5]  [140/183]  eta: 0:01:19  lr: 0.000500  loss: 0.1929 (0.2203)  loss_classifier: 0.0708 (0.0840)  loss_box_reg: 0.0947 (0.0983)  loss_objectness: 0.0060 (0.0109)  loss_rpn_box_reg: 0.0136 (0.0272)  time: 1.8353  data: 0.0271  max mem: 8528
# Epoch: [5]  [150/183]  eta: 0:01:01  lr: 0.000500  loss: 0.2109 (0.2208)  loss_classifier: 0.0824 (0.0840)  loss_box_reg: 0.0954 (0.0986)  loss_objectness: 0.0081 (0.0110)  loss_rpn_box_reg: 0.0158 (0.0272)  time: 1.8346  data: 0.0282  max mem: 8528
# Epoch: [5]  [160/183]  eta: 0:00:42  lr: 0.000500  loss: 0.2237 (0.2219)  loss_classifier: 0.0781 (0.0843)  loss_box_reg: 0.0913 (0.0988)  loss_objectness: 0.0119 (0.0112)  loss_rpn_box_reg: 0.0219 (0.0276)  time: 1.8387  data: 0.0299  max mem: 8528
# Epoch: [5]  [170/183]  eta: 0:00:24  lr: 0.000500  loss: 0.1942 (0.2201)  loss_classifier: 0.0695 (0.0835)  loss_box_reg: 0.0845 (0.0980)  loss_objectness: 0.0108 (0.0112)  loss_rpn_box_reg: 0.0211 (0.0273)  time: 1.8393  data: 0.0288  max mem: 8528
# Epoch: [5]  [180/183]  eta: 0:00:05  lr: 0.000500  loss: 0.2031 (0.2214)  loss_classifier: 0.0766 (0.0843)  loss_box_reg: 0.0888 (0.0986)  loss_objectness: 0.0097 (0.0113)  loss_rpn_box_reg: 0.0195 (0.0272)  time: 1.8353  data: 0.0266  max mem: 8528
# Epoch: [5]  [182/183]  eta: 0:00:01  lr: 0.000500  loss: 0.2067 (0.2213)  loss_classifier: 0.0776 (0.0844)  loss_box_reg: 0.0954 (0.0984)  loss_objectness: 0.0097 (0.0112)  loss_rpn_box_reg: 0.0195 (0.0273)  time: 1.7811  data: 0.0254  max mem: 8528
# Epoch: [5] Total time: 0:05:37 (1.8438 s / it)
# creating index...
# index created!
# Test:  [ 0/46]  eta: 0:01:44  model_time: 0.8844 (0.8844)  evaluator_time: 0.0253 (0.0253)  time: 2.2692  data: 1.3439  max mem: 8528
# Test:  [45/46]  eta: 0:00:00  model_time: 0.8407 (0.8362)  evaluator_time: 0.0125 (0.0156)  time: 0.8781  data: 0.0248  max mem: 8528
# Test: Total time: 0:00:41 (0.9118 s / it)
# Averaged stats: model_time: 0.8407 (0.8362)  evaluator_time: 0.0125 (0.0156)
# Accumulating evaluation results...
# DONE (t=0.23s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.246
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.496
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.223
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.236
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.260
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.263
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.411
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.404
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.341
# Epoch: [6]  [  0/183]  eta: 0:13:04  lr: 0.000050  loss: 0.2594 (0.2594)  loss_classifier: 0.1185 (0.1185)  loss_box_reg: 0.1132 (0.1132)  loss_objectness: 0.0055 (0.0055)  loss_rpn_box_reg: 0.0221 (0.0221)  time: 4.2882  data: 1.9620  max mem: 8528
# Epoch: [6]  [ 10/183]  eta: 0:05:57  lr: 0.000050  loss: 0.2215 (0.2240)  loss_classifier: 0.0847 (0.0893)  loss_box_reg: 0.0967 (0.1010)  loss_objectness: 0.0112 (0.0105)  loss_rpn_box_reg: 0.0156 (0.0232)  time: 2.0638  data: 0.1981  max mem: 8528
# Epoch: [6]  [ 20/183]  eta: 0:05:17  lr: 0.000050  loss: 0.2018 (0.2127)  loss_classifier: 0.0714 (0.0818)  loss_box_reg: 0.0922 (0.0956)  loss_objectness: 0.0096 (0.0105)  loss_rpn_box_reg: 0.0166 (0.0249)  time: 1.8295  data: 0.0248  max mem: 8528
# Epoch: [6]  [ 30/183]  eta: 0:04:52  lr: 0.000050  loss: 0.1994 (0.2151)  loss_classifier: 0.0731 (0.0824)  loss_box_reg: 0.0894 (0.0980)  loss_objectness: 0.0090 (0.0106)  loss_rpn_box_reg: 0.0232 (0.0241)  time: 1.8276  data: 0.0268  max mem: 8528
# Epoch: [6]  [ 40/183]  eta: 0:04:31  lr: 0.000050  loss: 0.2073 (0.2128)  loss_classifier: 0.0814 (0.0815)  loss_box_reg: 0.0894 (0.0969)  loss_objectness: 0.0086 (0.0102)  loss_rpn_box_reg: 0.0216 (0.0242)  time: 1.8498  data: 0.0278  max mem: 8528
# Epoch: [6]  [ 50/183]  eta: 0:04:11  lr: 0.000050  loss: 0.2123 (0.2182)  loss_classifier: 0.0842 (0.0845)  loss_box_reg: 0.0920 (0.0995)  loss_objectness: 0.0091 (0.0101)  loss_rpn_box_reg: 0.0208 (0.0241)  time: 1.8555  data: 0.0291  max mem: 8528
# Epoch: [6]  [ 60/183]  eta: 0:03:51  lr: 0.000050  loss: 0.2055 (0.2142)  loss_classifier: 0.0765 (0.0829)  loss_box_reg: 0.0878 (0.0968)  loss_objectness: 0.0092 (0.0101)  loss_rpn_box_reg: 0.0191 (0.0243)  time: 1.8440  data: 0.0287  max mem: 8528
# Epoch: [6]  [ 70/183]  eta: 0:03:32  lr: 0.000050  loss: 0.2063 (0.2177)  loss_classifier: 0.0838 (0.0843)  loss_box_reg: 0.0845 (0.0979)  loss_objectness: 0.0113 (0.0107)  loss_rpn_box_reg: 0.0182 (0.0248)  time: 1.8428  data: 0.0283  max mem: 8528
# Epoch: [6]  [ 80/183]  eta: 0:03:13  lr: 0.000050  loss: 0.2162 (0.2185)  loss_classifier: 0.0840 (0.0839)  loss_box_reg: 0.0948 (0.0980)  loss_objectness: 0.0100 (0.0106)  loss_rpn_box_reg: 0.0246 (0.0260)  time: 1.8518  data: 0.0273  max mem: 8528
# Epoch: [6]  [ 90/183]  eta: 0:02:53  lr: 0.000050  loss: 0.2063 (0.2156)  loss_classifier: 0.0753 (0.0830)  loss_box_reg: 0.0883 (0.0965)  loss_objectness: 0.0081 (0.0108)  loss_rpn_box_reg: 0.0186 (0.0253)  time: 1.8473  data: 0.0271  max mem: 8528
# Epoch: [6]  [100/183]  eta: 0:02:34  lr: 0.000050  loss: 0.1958 (0.2172)  loss_classifier: 0.0795 (0.0840)  loss_box_reg: 0.0930 (0.0970)  loss_objectness: 0.0078 (0.0108)  loss_rpn_box_reg: 0.0184 (0.0254)  time: 1.8369  data: 0.0266  max mem: 8528
# Epoch: [6]  [110/183]  eta: 0:02:16  lr: 0.000050  loss: 0.2004 (0.2160)  loss_classifier: 0.0738 (0.0833)  loss_box_reg: 0.0930 (0.0966)  loss_objectness: 0.0079 (0.0109)  loss_rpn_box_reg: 0.0219 (0.0252)  time: 1.8369  data: 0.0272  max mem: 8528
# Epoch: [6]  [120/183]  eta: 0:01:57  lr: 0.000050  loss: 0.1844 (0.2146)  loss_classifier: 0.0641 (0.0827)  loss_box_reg: 0.0786 (0.0956)  loss_objectness: 0.0079 (0.0107)  loss_rpn_box_reg: 0.0236 (0.0257)  time: 1.8423  data: 0.0277  max mem: 8528
# Epoch: [6]  [130/183]  eta: 0:01:38  lr: 0.000050  loss: 0.1934 (0.2132)  loss_classifier: 0.0772 (0.0821)  loss_box_reg: 0.0804 (0.0952)  loss_objectness: 0.0073 (0.0105)  loss_rpn_box_reg: 0.0218 (0.0254)  time: 1.8467  data: 0.0302  max mem: 8528
# Epoch: [6]  [140/183]  eta: 0:01:20  lr: 0.000050  loss: 0.2060 (0.2148)  loss_classifier: 0.0801 (0.0821)  loss_box_reg: 0.0976 (0.0962)  loss_objectness: 0.0076 (0.0105)  loss_rpn_box_reg: 0.0218 (0.0259)  time: 1.8488  data: 0.0307  max mem: 8528
# Epoch: [6]  [150/183]  eta: 0:01:01  lr: 0.000050  loss: 0.2172 (0.2148)  loss_classifier: 0.0785 (0.0822)  loss_box_reg: 0.0976 (0.0962)  loss_objectness: 0.0079 (0.0105)  loss_rpn_box_reg: 0.0260 (0.0259)  time: 1.8477  data: 0.0282  max mem: 8528
# Epoch: [6]  [160/183]  eta: 0:00:42  lr: 0.000050  loss: 0.2284 (0.2190)  loss_classifier: 0.0898 (0.0835)  loss_box_reg: 0.0935 (0.0973)  loss_objectness: 0.0102 (0.0114)  loss_rpn_box_reg: 0.0302 (0.0269)  time: 1.8402  data: 0.0281  max mem: 8528
# Epoch: [6]  [170/183]  eta: 0:00:24  lr: 0.000050  loss: 0.2506 (0.2200)  loss_classifier: 0.0880 (0.0836)  loss_box_reg: 0.0993 (0.0980)  loss_objectness: 0.0100 (0.0114)  loss_rpn_box_reg: 0.0337 (0.0271)  time: 1.8378  data: 0.0279  max mem: 8528
# Epoch: [6]  [180/183]  eta: 0:00:05  lr: 0.000050  loss: 0.2149 (0.2192)  loss_classifier: 0.0787 (0.0833)  loss_box_reg: 0.0991 (0.0976)  loss_objectness: 0.0081 (0.0114)  loss_rpn_box_reg: 0.0218 (0.0270)  time: 1.8289  data: 0.0270  max mem: 8528
# Epoch: [6]  [182/183]  eta: 0:00:01  lr: 0.000050  loss: 0.2162 (0.2195)  loss_classifier: 0.0806 (0.0833)  loss_box_reg: 0.0991 (0.0978)  loss_objectness: 0.0081 (0.0115)  loss_rpn_box_reg: 0.0269 (0.0269)  time: 1.7768  data: 0.0264  max mem: 8528
# Epoch: [6] Total time: 0:05:38 (1.8497 s / it)
# creating index...
# index created!
# Test:  [ 0/46]  eta: 0:01:33  model_time: 0.9237 (0.9237)  evaluator_time: 0.0208 (0.0208)  time: 2.0262  data: 1.0750  max mem: 8528
# Test:  [45/46]  eta: 0:00:00  model_time: 0.8412 (0.8383)  evaluator_time: 0.0165 (0.0171)  time: 0.8731  data: 0.0249  max mem: 8528
# Test: Total time: 0:00:41 (0.9115 s / it)
# Averaged stats: model_time: 0.8412 (0.8383)  evaluator_time: 0.0165 (0.0171)
# Accumulating evaluation results...
# DONE (t=0.27s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.248
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.494
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.236
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.262
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.414
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.386
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.402
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.338
# Epoch: [7]  [  0/183]  eta: 0:10:22  lr: 0.000050  loss: 0.1936 (0.1936)  loss_classifier: 0.0853 (0.0853)  loss_box_reg: 0.0790 (0.0790)  loss_objectness: 0.0104 (0.0104)  loss_rpn_box_reg: 0.0189 (0.0189)  time: 3.3996  data: 1.3938  max mem: 8528
# Epoch: [7]  [ 10/183]  eta: 0:05:39  lr: 0.000050  loss: 0.1936 (0.1911)  loss_classifier: 0.0715 (0.0703)  loss_box_reg: 0.0790 (0.0828)  loss_objectness: 0.0104 (0.0105)  loss_rpn_box_reg: 0.0189 (0.0275)  time: 1.9628  data: 0.1468  max mem: 8528
# Epoch: [7]  [ 20/183]  eta: 0:05:08  lr: 0.000050  loss: 0.1955 (0.1930)  loss_classifier: 0.0691 (0.0721)  loss_box_reg: 0.0841 (0.0881)  loss_objectness: 0.0085 (0.0095)  loss_rpn_box_reg: 0.0171 (0.0233)  time: 1.8158  data: 0.0250  max mem: 8528
# Epoch: [7]  [ 30/183]  eta: 0:04:47  lr: 0.000050  loss: 0.1975 (0.2081)  loss_classifier: 0.0743 (0.0777)  loss_box_reg: 0.0924 (0.0948)  loss_objectness: 0.0096 (0.0108)  loss_rpn_box_reg: 0.0190 (0.0248)  time: 1.8283  data: 0.0281  max mem: 8528
# Epoch: [7]  [ 40/183]  eta: 0:04:28  lr: 0.000050  loss: 0.2302 (0.2115)  loss_classifier: 0.0798 (0.0792)  loss_box_reg: 0.0911 (0.0949)  loss_objectness: 0.0096 (0.0103)  loss_rpn_box_reg: 0.0245 (0.0271)  time: 1.8564  data: 0.0284  max mem: 8528
# Epoch: [7]  [ 50/183]  eta: 0:04:08  lr: 0.000050  loss: 0.2130 (0.2155)  loss_classifier: 0.0741 (0.0807)  loss_box_reg: 0.0911 (0.0966)  loss_objectness: 0.0095 (0.0103)  loss_rpn_box_reg: 0.0277 (0.0280)  time: 1.8637  data: 0.0301  max mem: 8528
# Epoch: [7]  [ 60/183]  eta: 0:03:49  lr: 0.000050  loss: 0.1922 (0.2125)  loss_classifier: 0.0713 (0.0802)  loss_box_reg: 0.0908 (0.0949)  loss_objectness: 0.0092 (0.0103)  loss_rpn_box_reg: 0.0245 (0.0271)  time: 1.8470  data: 0.0294  max mem: 8528
# Epoch: [7]  [ 70/183]  eta: 0:03:30  lr: 0.000050  loss: 0.2010 (0.2119)  loss_classifier: 0.0780 (0.0803)  loss_box_reg: 0.0897 (0.0949)  loss_objectness: 0.0080 (0.0102)  loss_rpn_box_reg: 0.0194 (0.0264)  time: 1.8351  data: 0.0261  max mem: 8528
# Epoch: [7]  [ 80/183]  eta: 0:03:11  lr: 0.000050  loss: 0.2103 (0.2134)  loss_classifier: 0.0813 (0.0810)  loss_box_reg: 0.0923 (0.0958)  loss_objectness: 0.0103 (0.0106)  loss_rpn_box_reg: 0.0194 (0.0261)  time: 1.8438  data: 0.0266  max mem: 8528
# Epoch: [7]  [ 90/183]  eta: 0:02:53  lr: 0.000050  loss: 0.2317 (0.2162)  loss_classifier: 0.0906 (0.0825)  loss_box_reg: 0.1041 (0.0975)  loss_objectness: 0.0110 (0.0107)  loss_rpn_box_reg: 0.0194 (0.0254)  time: 1.8588  data: 0.0274  max mem: 8528
# ...
# Epoch: [17]  [150/183]  eta: 0:01:00  lr: 0.000000  loss: 0.2110 (0.2179)  loss_classifier: 0.0719 (0.0827)  loss_box_reg: 0.0915 (0.0980)  loss_objectness: 0.0098 (0.0112)  loss_rpn_box_reg: 0.0193 (0.0261)  time: 1.8395  data: 0.0270  max mem: 8528
# Epoch: [17]  [160/183]  eta: 0:00:42  lr: 0.000000  loss: 0.2109 (0.2175)  loss_classifier: 0.0719 (0.0825)  loss_box_reg: 0.0896 (0.0977)  loss_objectness: 0.0113 (0.0112)  loss_rpn_box_reg: 0.0225 (0.0260)  time: 1.8461  data: 0.0278  max mem: 8528
# Epoch: [17]  [170/183]  eta: 0:00:24  lr: 0.000000  loss: 0.2024 (0.2174)  loss_classifier: 0.0839 (0.0828)  loss_box_reg: 0.0864 (0.0973)  loss_objectness: 0.0086 (0.0111)  loss_rpn_box_reg: 0.0207 (0.0262)  time: 1.8463  data: 0.0309  max mem: 8528
# Epoch: [17]  [180/183]  eta: 0:00:05  lr: 0.000000  loss: 0.1991 (0.2177)  loss_classifier: 0.0789 (0.0828)  loss_box_reg: 0.0907 (0.0972)  loss_objectness: 0.0086 (0.0110)  loss_rpn_box_reg: 0.0206 (0.0267)  time: 1.8312  data: 0.0300  max mem: 8528
# Epoch: [17]  [182/183]  eta: 0:00:01  lr: 0.000000  loss: 0.1960 (0.2167)  loss_classifier: 0.0689 (0.0823)  loss_box_reg: 0.0864 (0.0967)  loss_objectness: 0.0086 (0.0109)  loss_rpn_box_reg: 0.0278 (0.0267)  time: 1.7716  data: 0.0268  max mem: 8528
# Epoch: [17] Total time: 0:05:36 (1.8395 s / it)
# creating index...
# index created!
# Test:  [ 0/46]  eta: 0:02:04  model_time: 1.1288 (1.1288)  evaluator_time: 0.1221 (0.1221)  time: 2.7127  data: 1.4427  max mem: 8528
# Test:  [45/46]  eta: 0:00:00  model_time: 0.8487 (0.8456)  evaluator_time: 0.0135 (0.0185)  time: 0.8751  data: 0.0240  max mem: 8528
# Test: Total time: 0:00:42 (0.9273 s / it)
# Averaged stats: model_time: 0.8487 (0.8456)  evaluator_time: 0.0135 (0.0185)
# Accumulating evaluation results...
# DONE (t=0.20s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.248
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.498
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.258
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.265
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.419
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.392
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.384
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.339
# Epoch: [18]  [  0/183]  eta: 0:09:57  lr: 0.000000  loss: 0.1167 (0.1167)  loss_classifier: 0.0341 (0.0341)  loss_box_reg: 0.0643 (0.0643)  loss_objectness: 0.0047 (0.0047)  loss_rpn_box_reg: 0.0136 (0.0136)  time: 3.2641  data: 1.2447  max mem: 8528
# Epoch: [18]  [ 10/183]  eta: 0:05:36  lr: 0.000000  loss: 0.1784 (0.1776)  loss_classifier: 0.0712 (0.0618)  loss_box_reg: 0.0771 (0.0792)  loss_objectness: 0.0086 (0.0090)  loss_rpn_box_reg: 0.0194 (0.0276)  time: 1.9448  data: 0.1355  max mem: 8528
# Epoch: [18]  [ 20/183]  eta: 0:05:06  lr: 0.000000  loss: 0.1887 (0.2061)  loss_classifier: 0.0735 (0.0748)  loss_box_reg: 0.0821 (0.0868)  loss_objectness: 0.0113 (0.0156)  loss_rpn_box_reg: 0.0194 (0.0290)  time: 1.8141  data: 0.0250  max mem: 8528
# Epoch: [18]  [ 30/183]  eta: 0:04:45  lr: 0.000000  loss: 0.2008 (0.1989)  loss_classifier: 0.0751 (0.0712)  loss_box_reg: 0.0896 (0.0874)  loss_objectness: 0.0106 (0.0135)  loss_rpn_box_reg: 0.0194 (0.0267)  time: 1.8233  data: 0.0262  max mem: 8528
# Epoch: [18]  [ 40/183]  eta: 0:04:26  lr: 0.000000  loss: 0.2062 (0.2029)  loss_classifier: 0.0633 (0.0731)  loss_box_reg: 0.0967 (0.0894)  loss_objectness: 0.0097 (0.0128)  loss_rpn_box_reg: 0.0212 (0.0277)  time: 1.8415  data: 0.0271  max mem: 8528
# Epoch: [18]  [ 50/183]  eta: 0:04:07  lr: 0.000000  loss: 0.2062 (0.2020)  loss_classifier: 0.0701 (0.0738)  loss_box_reg: 0.0947 (0.0896)  loss_objectness: 0.0088 (0.0119)  loss_rpn_box_reg: 0.0226 (0.0268)  time: 1.8491  data: 0.0264  max mem: 8528
# Epoch: [18]  [ 60/183]  eta: 0:03:48  lr: 0.000000  loss: 0.2096 (0.2080)  loss_classifier: 0.0779 (0.0772)  loss_box_reg: 0.0944 (0.0924)  loss_objectness: 0.0082 (0.0118)  loss_rpn_box_reg: 0.0225 (0.0266)  time: 1.8415  data: 0.0270  max mem: 8528
# Epoch: [18]  [ 70/183]  eta: 0:03:29  lr: 0.000000  loss: 0.2096 (0.2073)  loss_classifier: 0.0806 (0.0770)  loss_box_reg: 0.0984 (0.0934)  loss_objectness: 0.0080 (0.0111)  loss_rpn_box_reg: 0.0196 (0.0257)  time: 1.8270  data: 0.0279  max mem: 8528
# Epoch: [18]  [ 80/183]  eta: 0:03:10  lr: 0.000000  loss: 0.1977 (0.2059)  loss_classifier: 0.0732 (0.0762)  loss_box_reg: 0.0882 (0.0920)  loss_objectness: 0.0068 (0.0109)  loss_rpn_box_reg: 0.0236 (0.0268)  time: 1.8256  data: 0.0283  max mem: 8528
# Epoch: [18]  [ 90/183]  eta: 0:02:51  lr: 0.000000  loss: 0.1977 (0.2075)  loss_classifier: 0.0713 (0.0771)  loss_box_reg: 0.0876 (0.0935)  loss_objectness: 0.0075 (0.0107)  loss_rpn_box_reg: 0.0236 (0.0263)  time: 1.8449  data: 0.0309  max mem: 8528
# Epoch: [18]  [100/183]  eta: 0:02:33  lr: 0.000000  loss: 0.2502 (0.2115)  loss_classifier: 0.0911 (0.0788)  loss_box_reg: 0.0965 (0.0940)  loss_objectness: 0.0084 (0.0110)  loss_rpn_box_reg: 0.0232 (0.0277)  time: 1.8528  data: 0.0315  max mem: 8528
# Epoch: [18]  [110/183]  eta: 0:02:14  lr: 0.000000  loss: 0.2215 (0.2117)  loss_classifier: 0.0840 (0.0787)  loss_box_reg: 0.0969 (0.0944)  loss_objectness: 0.0088 (0.0108)  loss_rpn_box_reg: 0.0265 (0.0278)  time: 1.8382  data: 0.0294  max mem: 8528
# Epoch: [18]  [120/183]  eta: 0:01:56  lr: 0.000000  loss: 0.1992 (0.2099)  loss_classifier: 0.0698 (0.0782)  loss_box_reg: 0.0902 (0.0940)  loss_objectness: 0.0077 (0.0105)  loss_rpn_box_reg: 0.0202 (0.0271)  time: 1.8285  data: 0.0269  max mem: 8528
# Epoch: [18]  [130/183]  eta: 0:01:37  lr: 0.000000  loss: 0.2016 (0.2120)  loss_classifier: 0.0721 (0.0799)  loss_box_reg: 0.0925 (0.0948)  loss_objectness: 0.0081 (0.0106)  loss_rpn_box_reg: 0.0199 (0.0267)  time: 1.8340  data: 0.0260  max mem: 8528
# Epoch: [18]  [140/183]  eta: 0:01:19  lr: 0.000000  loss: 0.2295 (0.2118)  loss_classifier: 0.0913 (0.0799)  loss_box_reg: 0.1014 (0.0950)  loss_objectness: 0.0110 (0.0105)  loss_rpn_box_reg: 0.0178 (0.0263)  time: 1.8425  data: 0.0276  max mem: 8528
# Epoch: [18]  [150/183]  eta: 0:01:00  lr: 0.000000  loss: 0.2093 (0.2151)  loss_classifier: 0.0820 (0.0815)  loss_box_reg: 0.0922 (0.0960)  loss_objectness: 0.0114 (0.0111)  loss_rpn_box_reg: 0.0167 (0.0265)  time: 1.8452  data: 0.0290  max mem: 8528
# Epoch: [18]  [160/183]  eta: 0:00:42  lr: 0.000000  loss: 0.1980 (0.2150)  loss_classifier: 0.0820 (0.0813)  loss_box_reg: 0.0902 (0.0961)  loss_objectness: 0.0100 (0.0109)  loss_rpn_box_reg: 0.0223 (0.0267)  time: 1.8366  data: 0.0272  max mem: 8528
# Epoch: [18]  [170/183]  eta: 0:00:23  lr: 0.000000  loss: 0.1980 (0.2160)  loss_classifier: 0.0811 (0.0818)  loss_box_reg: 0.0902 (0.0961)  loss_objectness: 0.0071 (0.0110)  loss_rpn_box_reg: 0.0235 (0.0270)  time: 1.8348  data: 0.0255  max mem: 8528
# Epoch: [18]  [180/183]  eta: 0:00:05  lr: 0.000000  loss: 0.2139 (0.2175)  loss_classifier: 0.0839 (0.0825)  loss_box_reg: 0.1000 (0.0971)  loss_objectness: 0.0116 (0.0111)  loss_rpn_box_reg: 0.0232 (0.0268)  time: 1.8334  data: 0.0263  max mem: 8528
# Epoch: [18]  [182/183]  eta: 0:00:01  lr: 0.000000  loss: 0.2096 (0.2179)  loss_classifier: 0.0838 (0.0829)  loss_box_reg: 0.0999 (0.0971)  loss_objectness: 0.0116 (0.0110)  loss_rpn_box_reg: 0.0235 (0.0269)  time: 1.7814  data: 0.0257  max mem: 8528
# Epoch: [18] Total time: 0:05:36 (1.8378 s / it)
# creating index...
# index created!
# Test:  [ 0/46]  eta: 0:01:34  model_time: 0.9181 (0.9181)  evaluator_time: 0.0455 (0.0455)  time: 2.0463  data: 1.0761  max mem: 8528
# Test:  [45/46]  eta: 0:00:00  model_time: 0.8368 (0.8386)  evaluator_time: 0.0140 (0.0166)  time: 0.8778  data: 0.0256  max mem: 8528
# Test: Total time: 0:00:41 (0.9117 s / it)
# Averaged stats: model_time: 0.8368 (0.8386)  evaluator_time: 0.0140 (0.0166)
# Accumulating evaluation results...
# DONE (t=0.36s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.248
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.498
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.258
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.265
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.419
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.392
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.384
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.339
# Epoch: [19]  [  0/183]  eta: 0:13:00  lr: 0.000000  loss: 0.1411 (0.1411)  loss_classifier: 0.0574 (0.0574)  loss_box_reg: 0.0647 (0.0647)  loss_objectness: 0.0026 (0.0026)  loss_rpn_box_reg: 0.0165 (0.0165)  time: 4.2637  data: 2.0245  max mem: 8528
# Epoch: [19]  [ 10/183]  eta: 0:05:52  lr: 0.000000  loss: 0.2528 (0.2451)  loss_classifier: 0.0951 (0.0950)  loss_box_reg: 0.1068 (0.1099)  loss_objectness: 0.0105 (0.0139)  loss_rpn_box_reg: 0.0283 (0.0263)  time: 2.0387  data: 0.2089  max mem: 8528
# Epoch: [19]  [ 20/183]  eta: 0:05:14  lr: 0.000000  loss: 0.2158 (0.2127)  loss_classifier: 0.0845 (0.0817)  loss_box_reg: 0.0961 (0.0954)  loss_objectness: 0.0092 (0.0110)  loss_rpn_box_reg: 0.0218 (0.0245)  time: 1.8156  data: 0.0276  max mem: 8528
# Epoch: [19]  [ 30/183]  eta: 0:04:51  lr: 0.000000  loss: 0.1955 (0.2187)  loss_classifier: 0.0748 (0.0833)  loss_box_reg: 0.0901 (0.0980)  loss_objectness: 0.0081 (0.0119)  loss_rpn_box_reg: 0.0200 (0.0255)  time: 1.8270  data: 0.0279  max mem: 8528
# Epoch: [19]  [ 40/183]  eta: 0:04:30  lr: 0.000000  loss: 0.2175 (0.2198)  loss_classifier: 0.0749 (0.0828)  loss_box_reg: 0.0968 (0.0983)  loss_objectness: 0.0088 (0.0125)  loss_rpn_box_reg: 0.0267 (0.0261)  time: 1.8452  data: 0.0275  max mem: 8528
# Epoch: [19]  [ 50/183]  eta: 0:04:10  lr: 0.000000  loss: 0.1924 (0.2141)  loss_classifier: 0.0687 (0.0803)  loss_box_reg: 0.0925 (0.0961)  loss_objectness: 0.0076 (0.0117)  loss_rpn_box_reg: 0.0218 (0.0260)  time: 1.8546  data: 0.0270  max mem: 8528
# Epoch: [19]  [ 60/183]  eta: 0:03:50  lr: 0.000000  loss: 0.1976 (0.2176)  loss_classifier: 0.0701 (0.0811)  loss_box_reg: 0.0925 (0.0969)  loss_objectness: 0.0078 (0.0132)  loss_rpn_box_reg: 0.0194 (0.0264)  time: 1.8524  data: 0.0292  max mem: 8528
# Epoch: [19]  [ 70/183]  eta: 0:03:31  lr: 0.000000  loss: 0.2028 (0.2160)  loss_classifier: 0.0744 (0.0807)  loss_box_reg: 0.0881 (0.0961)  loss_objectness: 0.0087 (0.0126)  loss_rpn_box_reg: 0.0197 (0.0266)  time: 1.8362  data: 0.0289  max mem: 8528
# Epoch: [19]  [ 80/183]  eta: 0:03:12  lr: 0.000000  loss: 0.2066 (0.2160)  loss_classifier: 0.0801 (0.0807)  loss_box_reg: 0.0917 (0.0964)  loss_objectness: 0.0089 (0.0122)  loss_rpn_box_reg: 0.0205 (0.0267)  time: 1.8275  data: 0.0262  max mem: 8528
# Epoch: [19]  [ 90/183]  eta: 0:02:53  lr: 0.000000  loss: 0.2066 (0.2158)  loss_classifier: 0.0746 (0.0815)  loss_box_reg: 0.0955 (0.0964)  loss_objectness: 0.0082 (0.0119)  loss_rpn_box_reg: 0.0205 (0.0260)  time: 1.8359  data: 0.0265  max mem: 8528
# Epoch: [19]  [100/183]  eta: 0:02:34  lr: 0.000000  loss: 0.1850 (0.2135)  loss_classifier: 0.0720 (0.0808)  loss_box_reg: 0.0803 (0.0958)  loss_objectness: 0.0082 (0.0117)  loss_rpn_box_reg: 0.0181 (0.0253)  time: 1.8418  data: 0.0268  max mem: 8528
# Epoch: [19]  [110/183]  eta: 0:02:15  lr: 0.000000  loss: 0.1913 (0.2131)  loss_classifier: 0.0721 (0.0805)  loss_box_reg: 0.0871 (0.0955)  loss_objectness: 0.0094 (0.0115)  loss_rpn_box_reg: 0.0193 (0.0255)  time: 1.8443  data: 0.0287  max mem: 8528
# Epoch: [19]  [120/183]  eta: 0:01:57  lr: 0.000000  loss: 0.2045 (0.2129)  loss_classifier: 0.0721 (0.0803)  loss_box_reg: 0.0905 (0.0955)  loss_objectness: 0.0084 (0.0113)  loss_rpn_box_reg: 0.0218 (0.0257)  time: 1.8443  data: 0.0282  max mem: 8528
# Epoch: [19]  [130/183]  eta: 0:01:38  lr: 0.000000  loss: 0.2044 (0.2140)  loss_classifier: 0.0725 (0.0805)  loss_box_reg: 0.0927 (0.0955)  loss_objectness: 0.0076 (0.0118)  loss_rpn_box_reg: 0.0180 (0.0262)  time: 1.8376  data: 0.0254  max mem: 8528
# Epoch: [19]  [140/183]  eta: 0:01:19  lr: 0.000000  loss: 0.2318 (0.2167)  loss_classifier: 0.0851 (0.0818)  loss_box_reg: 0.0950 (0.0968)  loss_objectness: 0.0096 (0.0119)  loss_rpn_box_reg: 0.0180 (0.0261)  time: 1.8368  data: 0.0276  max mem: 8528
# Epoch: [19]  [150/183]  eta: 0:01:01  lr: 0.000000  loss: 0.2200 (0.2170)  loss_classifier: 0.0875 (0.0820)  loss_box_reg: 0.1014 (0.0968)  loss_objectness: 0.0097 (0.0118)  loss_rpn_box_reg: 0.0238 (0.0264)  time: 1.8363  data: 0.0291  max mem: 8528
# Epoch: [19]  [160/183]  eta: 0:00:42  lr: 0.000000  loss: 0.2172 (0.2181)  loss_classifier: 0.0882 (0.0829)  loss_box_reg: 0.0921 (0.0971)  loss_objectness: 0.0097 (0.0118)  loss_rpn_box_reg: 0.0191 (0.0263)  time: 1.8371  data: 0.0293  max mem: 8528
# Epoch: [19]  [170/183]  eta: 0:00:24  lr: 0.000000  loss: 0.2224 (0.2182)  loss_classifier: 0.0875 (0.0827)  loss_box_reg: 0.0989 (0.0973)  loss_objectness: 0.0101 (0.0118)  loss_rpn_box_reg: 0.0187 (0.0264)  time: 1.8407  data: 0.0306  max mem: 8528
# Epoch: [19]  [180/183]  eta: 0:00:05  lr: 0.000000  loss: 0.2242 (0.2185)  loss_classifier: 0.0835 (0.0830)  loss_box_reg: 0.0967 (0.0972)  loss_objectness: 0.0099 (0.0117)  loss_rpn_box_reg: 0.0240 (0.0266)  time: 1.8409  data: 0.0290  max mem: 8528
# Epoch: [19]  [182/183]  eta: 0:00:01  lr: 0.000000  loss: 0.2242 (0.2185)  loss_classifier: 0.0832 (0.0828)  loss_box_reg: 0.0967 (0.0973)  loss_objectness: 0.0101 (0.0117)  loss_rpn_box_reg: 0.0280 (0.0267)  time: 1.7849  data: 0.0277  max mem: 8528
# Epoch: [19] Total time: 0:05:37 (1.8457 s / it)
# creating index...
# index created!
# Test:  [ 0/46]  eta: 0:01:38  model_time: 0.9099 (0.9099)  evaluator_time: 0.0231 (0.0231)  time: 2.1474  data: 1.2019  max mem: 8528
# Test:  [45/46]  eta: 0:00:00  model_time: 0.8397 (0.8422)  evaluator_time: 0.0137 (0.0165)  time: 0.8705  data: 0.0252  max mem: 8528
# Test: Total time: 0:00:42 (0.9163 s / it)
# Averaged stats: model_time: 0.8397 (0.8422)  evaluator_time: 0.0137 (0.0165)
# Accumulating evaluation results...
# DONE (t=0.22s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.248
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.498
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.258
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.265
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.419
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.392
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.384
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.339

# %%
def apply_nms(orig_prediction, iou_thresh=0.3):

    # torchvision returns the indices of the bboxes to keep
    keep = torchvision.ops.nms(orig_prediction['boxes'], orig_prediction['scores'], iou_thresh)

    final_prediction = orig_prediction
    final_prediction['boxes'] = final_prediction['boxes'][keep]
    final_prediction['scores'] = final_prediction['scores'][keep]
    final_prediction['labels'] = final_prediction['labels'][keep]

    return final_prediction

# function to convert a torchtensor back to PIL image
def torch_to_pil(img):
    return torchtrans.ToPILImage()(img).convert('RGB')

# %%
dataset_test = GC10Dataset(file_dir, annotation_dir, 224, 224, transforms= get_transform(train=True))
# pick one image from the test set
img, target = dataset_test[35]
# put the model in evaluation mode
model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])[0]

print('EXPECTED OUTPUT\n')
plot_img_bbox(torch_to_pil(img), target)
print('MODEL OUTPUT\n')
nms_prediction = apply_nms(prediction, iou_thresh=0.2)

plot_img_bbox(torch_to_pil(img), nms_prediction)
# Out:
# EXPECTED OUTPUT
# MODEL OUTPUT

# %%
# Assuming `model` is your trained model
model_save_path = '/content/gdrive/MyDrive/Colab Notebooks/Faster RCNN/fasterrcnn_resnet50_model_weights.pth'  # Specify the path and filename
torch.save(model.state_dict(), model_save_path)
print("Complete")
# Out:
# Complete
